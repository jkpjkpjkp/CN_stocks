# %%
import polars as pl
df = pl.scan_parquet('/dev/shm/013000_013500.pq').filter(pl.col.id < 13100).collect()
df
# Out:
# shape: (294_677_306, 3)
# ┌─────────────────────────┬───────┬───────┐
# │ datetime                ┆ close ┆ id    │
# │ ---                     ┆ ---   ┆ ---   │
# │ datetime[ms]            ┆ i32   ┆ i16   │
# ╞═════════════════════════╪═══════╪═══════╡
# │ 2010-07-05 09:23:02     ┆ 0     ┆ 13000 │
# │ 2010-07-05 09:23:07     ┆ 0     ┆ 13000 │
# │ 2010-07-05 09:23:12     ┆ 0     ┆ 13000 │
# │ 2010-07-05 09:23:17     ┆ 0     ┆ 13000 │
# │ 2010-07-05 09:23:22     ┆ 0     ┆ 13000 │
# │ …                       ┆ …     ┆ …     │
# │ 2024-12-31 14:56:51.290 ┆ 426   ┆ 13099 │
# │ 2024-12-31 14:56:54.289 ┆ 427   ┆ 13099 │
# │ 2024-12-31 14:56:57.377 ┆ 426   ┆ 13099 │
# │ 2024-12-31 15:00:00.293 ┆ 427   ┆ 13099 │
# │ 2024-12-31 15:00:03.289 ┆ 426   ┆ 13099 │
# └─────────────────────────┴───────┴───────┘

# %%
df = df.filter(pl.col.close > 0)

# %%
df['close']
# Out:
# shape: (294_665_002,)
# Series: 'close' [i32]
# [
# 	800
# 	800
# 	799
# 	799
# 	793
# 	…
# 	426
# 	427
# 	426
# 	427
# 	426
# ]

# %%
df['id'].unique()
# Out:
# shape: (37,)
# Series: 'id' [i16]
# [
# 	13000
# 	13001
# 	13002
# 	13003
# 	13005
# 	…
# 	13088
# 	13089
# 	13096
# 	13098
# 	13099
# ]

# %%
df.group_by('id').agg(pl.col.datetime.last() - pl.col.datetime.first())
# Out:
# shape: (37, 2)
# ┌───────┬────────────────────────┐
# │ id    ┆ datetime               │
# │ ---   ┆ ---                    │
# │ i16   ┆ duration[ms]           │
# ╞═══════╪════════════════════════╡
# │ 13002 ┆ 5475d 5h 37m 793ms     │
# │ 13005 ┆ 5475d 5h 37m 709ms     │
# │ 13008 ┆ 5475d 5h 36m 56s 151ms │
# │ 13011 ┆ 5046d 5h 34m 57s 585ms │
# │ 13020 ┆ 3212d 5h 34m 58s 91ms  │
# │ …     ┆ …                      │
# │ 13022 ┆ 754d 5h 37m 7s 286ms   │
# │ 13028 ┆ 4803d 5h 34m 58s 770ms │
# │ 13058 ┆ 4933d 5h 35m 1s 304ms  │
# │ 13061 ┆ 631d 5h 37m 8s 476ms   │
# │ 13088 ┆ 5475d 5h 37m 133ms     │
# └───────┴────────────────────────┘

# %%
df.filter(pl.col.id == 13002)
# Out:
# shape: (10_831_122, 3)
# ┌─────────────────────────┬───────┬───────┐
# │ datetime                ┆ close ┆ id    │
# │ ---                     ┆ ---   ┆ ---   │
# │ datetime[ms]            ┆ i32   ┆ i16   │
# ╞═════════════════════════╪═══════╪═══════╡
# │ 2010-01-04 09:23:04     ┆ 793   ┆ 13002 │
# │ 2010-01-04 09:23:24     ┆ 793   ┆ 13002 │
# │ 2010-01-04 09:23:49     ┆ 793   ┆ 13002 │
# │ 2010-01-04 09:23:54     ┆ 793   ┆ 13002 │
# │ 2010-01-04 09:24:04     ┆ 793   ┆ 13002 │
# │ …                       ┆ …     ┆ …     │
# │ 2024-12-31 14:56:52.794 ┆ 434   ┆ 13002 │
# │ 2024-12-31 14:56:55.811 ┆ 434   ┆ 13002 │
# │ 2024-12-31 14:56:58.804 ┆ 435   ┆ 13002 │
# │ 2024-12-31 15:00:01.784 ┆ 435   ┆ 13002 │
# │ 2024-12-31 15:00:04.793 ┆ 435   ┆ 13002 │
# └─────────────────────────┴───────┴───────┘

# %%
x = df.filter(pl.col.datetime.dt.time() < time(9, 25, 00)).group_by('id', pl.col.datetime.dt.date()).agg(pl.col.close.unique())

# %%
df = df.filter(pl.col.datetime.dt.time() >= time(9, 24, 50))

# %%
x.sort(pl.col.close.list.len())
# Out:
# shape: (63_036, 3)
# ┌───────┬────────────┬──────────────┐
# │ id    ┆ datetime   ┆ close        │
# │ ---   ┆ ---        ┆ ---          │
# │ i16   ┆ date       ┆ list[i32]    │
# ╞═══════╪════════════╪══════════════╡
# │ 13020 ┆ 2020-04-16 ┆ [840]        │
# │ 13088 ┆ 2012-04-24 ┆ [2640]       │
# │ 13015 ┆ 2022-10-11 ┆ [504]        │
# │ 13099 ┆ 2022-09-22 ┆ [265]        │
# │ 13005 ┆ 2021-06-09 ┆ [270]        │
# │ …     ┆ …          ┆ …            │
# │ 13099 ┆ 2014-03-31 ┆ [632, 634]   │
# │ 13006 ┆ 2011-10-21 ┆ [734, 738]   │
# │ 13002 ┆ 2011-10-21 ┆ [1284, 1286] │
# │ 13088 ┆ 2011-06-20 ┆ [2767, 2792] │
# │ 13009 ┆ 2014-03-31 ┆ [776, 778]   │
# └───────┴────────────┴──────────────┘

# %%
from datetime import time, date
df.filter(pl.col.datetime.dt.time() <= time(9, 30, 20)).filter(pl.col.id == 13002).filter(pl.col.datetime.dt.date() == date(2011, 10, 21))
# Out:
# shape: (6, 3)
# ┌─────────────────────┬───────┬───────┐
# │ datetime            ┆ close ┆ id    │
# │ ---                 ┆ ---   ┆ ---   │
# │ datetime[ms]        ┆ i32   ┆ i16   │
# ╞═════════════════════╪═══════╪═══════╡
# │ 2011-10-21 09:24:59 ┆ 1286  ┆ 13002 │
# │ 2011-10-21 09:24:59 ┆ 1284  ┆ 13002 │
# │ 2011-10-21 09:30:05 ┆ 1280  ┆ 13002 │
# │ 2011-10-21 09:30:09 ┆ 1280  ┆ 13002 │
# │ 2011-10-21 09:30:14 ┆ 1280  ┆ 13002 │
# │ 2011-10-21 09:30:19 ┆ 1280  ┆ 13002 │
# └─────────────────────┴───────┴───────┘

# %%
y = df.select((pl.col.datetime - pl.col.datetime.shift(1).over('id')))

# %%
y.drop_nulls()
# Out:
# shape: (293_598_412, 1)
# ┌──────────────┐
# │ datetime     │
# │ ---          │
# │ duration[ms] │
# ╞══════════════╡
# │ 4m 55s       │
# │ 5s           │
# │ 5s           │
# │ 5s           │
# │ 5s           │
# │ …            │
# │ 3s 1ms       │
# │ 2s 999ms     │
# │ 3s 88ms      │
# │ 3m 2s 916ms  │
# │ 2s 996ms     │
# └──────────────┘

# %%
y.filter(pl.col.datetime < pl.duration(seconds=2))
# Out:
# shape: (5_339_655, 1)
# ┌──────────────┐
# │ datetime     │
# │ ---          │
# │ duration[ms] │
# ╞══════════════╡
# │ 0ms          │
# │ 0ms          │
# │ 0ms          │
# │ 0ms          │
# │ 0ms          │
# │ …            │
# │ 83ms         │
# │ 2ms          │
# │ 82ms         │
# │ 2ms          │
# │ 4ms          │
# └──────────────┘

# %%
df.filter(pl.col.datetime == pl.col.datetime.shift(1).over('id'))
# Out:
# shape: (306_121, 3)
# ┌─────────────────────────┬───────┬───────┐
# │ datetime                ┆ close ┆ id    │
# │ ---                     ┆ ---   ┆ ---   │
# │ datetime[ms]            ┆ i32   ┆ i16   │
# ╞═════════════════════════╪═══════╪═══════╡
# │ 2010-07-05 09:31:37     ┆ 797   ┆ 13000 │
# │ 2010-07-05 11:08:28     ┆ 795   ┆ 13000 │
# │ 2010-07-05 13:01:38     ┆ 795   ┆ 13000 │
# │ 2010-07-05 14:53:33     ┆ 789   ┆ 13000 │
# │ 2010-07-07 10:38:51     ┆ 764   ┆ 13000 │
# │ …                       ┆ …     ┆ …     │
# │ 2019-04-12 13:26:50     ┆ 424   ┆ 13099 │
# │ 2019-04-12 13:39:47     ┆ 421   ┆ 13099 │
# │ 2019-04-12 13:54:23     ┆ 422   ┆ 13099 │
# │ 2019-04-12 14:28:35     ┆ 425   ┆ 13099 │
# │ 2019-04-23 09:30:35.980 ┆ 415   ┆ 13099 │
# └─────────────────────────┴───────┴───────┘

# %%
df.filter(pl.col.datetime == pl.col.datetime.shift(-1).over('id'))
# Out:
# shape: (306_121, 3)
# ┌─────────────────────────┬───────┬───────┐
# │ datetime                ┆ close ┆ id    │
# │ ---                     ┆ ---   ┆ ---   │
# │ datetime[ms]            ┆ i32   ┆ i16   │
# ╞═════════════════════════╪═══════╪═══════╡
# │ 2010-07-05 09:31:37     ┆ 794   ┆ 13000 │
# │ 2010-07-05 11:08:28     ┆ 796   ┆ 13000 │
# │ 2010-07-05 13:01:38     ┆ 796   ┆ 13000 │
# │ 2010-07-05 14:53:33     ┆ 788   ┆ 13000 │
# │ 2010-07-07 10:38:51     ┆ 765   ┆ 13000 │
# │ …                       ┆ …     ┆ …     │
# │ 2019-04-12 13:26:50     ┆ 423   ┆ 13099 │
# │ 2019-04-12 13:39:47     ┆ 422   ┆ 13099 │
# │ 2019-04-12 13:54:23     ┆ 421   ┆ 13099 │
# │ 2019-04-12 14:28:35     ┆ 426   ┆ 13099 │
# │ 2019-04-23 09:30:35.980 ┆ 414   ┆ 13099 │
# └─────────────────────────┴───────┴───────┘

# %%
df = df.filter(pl.col.datetime.ne(pl.col.datetime.shift(1).over('id')) | pl.col.close.ne(pl.col.close.shift(1).over('id')))

# %%
sorry = df.filter(pl.col.datetime == pl.col.datetime.shift(1).over('id'))

# %%
df = df.filter(pl.col.datetime != pl.col.datetime.shift(1).over('id'))

# %%
delta = df.with_columns(delta = pl.when(pl.col.id.eq(pl.col.id.shift(1) & pl.col.datetime-pl.col.datetime.shift(1)<pl.duration(hours=1))).then(pl.col.close - pl.col.close.shift(1)).otherwise(-9999)
                  ).select(pl.when(pl.col.delta.abs() < 64).then(pl.col.delta + 64).otherwise(0).cast(pl.UInt8))
# Out:
# shape: (292_573_869, 3)
# ┌─────────────────────────┬───────┬───────┐
# │ datetime                ┆ close ┆ id    │
# │ ---                     ┆ ---   ┆ ---   │
# │ datetime[ms]            ┆ i32   ┆ i16   │
# ╞═════════════════════════╪═══════╪═══════╡
# │ 2010-07-05 09:30:07     ┆ 799   ┆ 13000 │
# │ 2010-07-05 09:30:12     ┆ 799   ┆ 13000 │
# │ 2010-07-05 09:30:17     ┆ 793   ┆ 13000 │
# │ 2010-07-05 09:30:22     ┆ 798   ┆ 13000 │
# │ 2010-07-05 09:30:27     ┆ 794   ┆ 13000 │
# │ …                       ┆ …     ┆ …     │
# │ 2024-12-31 14:56:51.290 ┆ 426   ┆ 13099 │
# │ 2024-12-31 14:56:54.289 ┆ 427   ┆ 13099 │
# │ 2024-12-31 14:56:57.377 ┆ 426   ┆ 13099 │
# │ 2024-12-31 15:00:00.293 ┆ 427   ┆ 13099 │
# │ 2024-12-31 15:00:03.289 ┆ 426   ┆ 13099 │
# └─────────────────────────┴───────┴───────┘

# %%
x = df.select((pl.col.datetime.dt.round('1s') - pl.col.datetime.dt.round('1s').shift(1).over('id')).value_counts())
pl.Config.set_tbl_rows(199)

x
# Out:
# shape: (1_347, 1)
# ┌──────────────────────┐
# │ datetime             │
# │ ---                  │
# │ struct[2]            │
# ╞══════════════════════╡
# │ {25s,323902}         │
# │ {9d 18h 27m 58s,2}   │
# │ {22s,31914}          │
# │ {2d 18h 24m 37s,22}  │
# │ {1h 29m 43s,2}       │
# │ {2d 19h 30m 1s,1}    │
# │ {1h 30m 49s,12}      │
# │ {1h 34m 30s,1}       │
# │ {1h 31m 18s,3}       │
# │ {55s,22426}          │
# │ {1m 28s,136}         │
# │ {7d 18h 28m 40s,1}   │
# │ {2m 55s,166}         │
# │ {18h 28m 59s,1}      │
# │ {2m 14s,17}          │
# │ {4d 18h 28m 7s,7}    │
# │ {4m 32s,16}          │
# │ {9d 18h 27m 55s,2}   │
# │ {1h 30m 53s,8}       │
# │ {1h 31m 22s,3}       │
# │ {18h 24m 32s,51}     │
# │ {3d 18h 25m 4s,5}    │
# │ {3d 18h 24m 55s,17}  │
# │ {9d 18h 25m 3s,6}    │
# │ {2d 18h 28m 15s,22}  │
# │ {1h 32m 20s,1}       │
# │ {1m 58s,55}          │
# │ {5d 18h 24m 36s,1}   │
# │ {2m 42s,54}          │
# │ {1m 14s,303}         │
# │ {1h 31m 24s,7}       │
# │ {5m 18s,2}           │
# │ {18h 28m 47s,1}      │
# │ {30m 3s,2}           │
# │ {1h 35m 7s,1}        │
# │ {7d 18h 28m 4s,3}    │
# │ {1h 3m 16s,1}        │
# │ {42m 29s,1}          │
# │ {18h 25m 3s,844}     │
# │ {2d 18h 24m 17s,4}   │
# │ {18h 28m 3s,621}     │
# │ {18h 24m 46s,4717}   │
# │ {43m 45s,7}          │
# │ {1d 18h 24m 28s,1}   │
# │ {2d 18h 27m 55s,111} │
# │ {18h 28m 4s,659}     │
# │ {9d 18h 24m 52s,7}   │
# │ {1m 55s,1175}        │
# │ {7d 18h 28m 8s,2}    │
# │ {7d 18h 24m 41s,3}   │
# │ {3d 18h 27m 51s,13}  │
# │ {18h 24m 48s,6097}   │
# │ {8d 18h 24m 49s,1}   │
# │ {9d 18h 28m 12s,1}   │
# │ {3m 51s,9}           │
# │ {18h 24m 56s,994}    │
# │ {2m 21s,105}         │
# │ {18h 24m 51s,3660}   │
# │ {2d 18h 33m 26s,1}   │
# │ {3d 18h 25m 11s,1}   │
# │ {4m 31s,46}          │
# │ {14m 36s,6}          │
# │ {2d 18h 28m 6s,145}  │
# │ {2m 48s,22}          │
# │ {3m 34s,23}          │
# │ {4m 28s,11}          │
# │ {22d 18h 24m 41s,1}  │
# │ {18h 24m 44s,1843}   │
# │ {1m 38s,55}          │
# │ {2m 44s,11}          │
# │ {7d 18h 24m 51s,13}  │
# │ {1h 29m 53s,14}      │
# │ {5d 18h 24m 42s,3}   │
# │ {2m 28s,8}           │
# │ {4d 18h 28m 10s,1}   │
# │ {1h 30m 6s,6698}     │
# │ {1h 30m 48s,25}      │
# │ {3d 18h 27m 56s,3}   │
# │ {3m 36s,30}          │
# │ {155d 18h 27m 51s,1} │
# │ {2m 31s,23}          │
# │ {5m 2s,2379}         │
# │ {1h 31m 11s,23}      │
# │ {1m 41s,147}         │
# │ {7d 18h 28m 15s,1}   │
# │ {1h 30m 23s,82}      │
# │ {18h 24m 30s,57}     │
# │ {2d 18h 24m 30s,15}  │
# │ {18h 24m 6s,1}       │
# │ {149d 18h 24m 59s,1} │
# │ {1h 31m 19s,1}       │
# │ {1h 32m 45s,1}       │
# │ {4m 38s,35}          │
# │ {2m 24s,92}          │
# │ {1m 49s,60}          │
# │ {3d 18h 24m 41s,4}   │
# │ {2d 18h 28m 25s,4}   │
# │ {44m 25s,1}          │
# │ {5d 18h 25m 4s,6}    │
# │ {31s,11530}          │
# │ …                    │
# │ {2d 18h 28m 29s,1}   │
# │ {1d 18h 25m 1s,1}    │
# │ {1d 18h 25m,7}       │
# │ {3d 18h 24m 53s,20}  │
# │ {5d 18h 24m 53s,7}   │
# │ {18h 28m 38s,4}      │
# │ {5m 14s,1}           │
# │ {2m 16s,28}          │
# │ {7d 18h 25m 7s,2}    │
# │ {2m 34s,3}           │
# │ {18h 27m 55s,406}    │
# │ {18h 24m 16s,14}     │
# │ {1h 30m 55s,37}      │
# │ {3m 23s,58}          │
# │ {9m 39s,1}           │
# │ {19h 29m 58s,1}      │
# │ {2m 39s,47}          │
# │ {9m 10s,1}           │
# │ {4d 18h 24m 21s,1}   │
# │ {21m 57s,1}          │
# │ {2d 18h 24m 23s,13}  │
# │ {2d 18h 25m 27s,3}   │
# │ {26s,23451}          │
# │ {3s,166547691}       │
# │ {4m 15s,126}         │
# │ {18h 24m 34s,52}     │
# │ {2m 3s,188}          │
# │ {2d 18h 28m 17s,11}  │
# │ {3d 18h 24m 21s,1}   │
# │ {18h 28m 2s,551}     │
# │ {3m 25s,175}         │
# │ {1m 22s,185}         │
# │ {6m 48s,1}           │
# │ {2d 18h 29m 17s,1}   │
# │ {13s,248556}         │
# │ {4d 18h 25m 3s,5}    │
# │ {1h 33m 20s,1}       │
# │ {5d 18h 24m 37s,2}   │
# │ {6m 57s,1}           │
# │ {1d 18h 25m 7s,2}    │
# │ {7s,3045286}         │
# │ {1h 32m 35s,2}       │
# │ {3d 18h 27m 59s,1}   │
# │ {7d 18h 28m 1s,1}    │
# │ {3d 18h 28m 1s,8}    │
# │ {4m 29s,106}         │
# │ {4m 7s,5}            │
# │ {3d 18h 25m 2s,30}   │
# │ {20m 57s,2}          │
# │ {2d 18h 28m 18s,10}  │
# │ {3m 13s,257}         │
# │ {9d 18h 24m 50s,9}   │
# │ {7d 18h 24m 57s,2}   │
# │ {5d 18h 24m 27s,2}   │
# │ {4d 18h 25m 13s,1}   │
# │ {1h 31m 23s,1}       │
# │ {1h 30m 36s,135}     │
# │ {2d 18h 25m 14s,3}   │
# │ {8d 18h 24m 47s,3}   │
# │ {1m 45s,2038}        │
# │ {5d 18h 24m 54s,5}   │
# │ {14m 41s,4}          │
# │ {30m,6}              │
# │ {1h 30m 35s,100}     │
# │ {2m 35s,331}         │
# │ {18h 24m 57s,1148}   │
# │ {2m 19s,28}          │
# │ {2d 18h 25m,568}     │
# │ {4d 18h 24m 50s,30}  │
# │ {4d 18h 25m,20}      │
# │ {18h 25m 27s,3}      │
# │ {1h 29m 51s,23}      │
# │ {28s,13310}          │
# │ {5d 18h 28m 10s,2}   │
# │ {1h 31m 26s,9}       │
# │ {1m 48s,361}         │
# │ {1h 30m 56s,34}      │
# │ {1h 30m 28s,117}     │
# │ {8s,1929053}         │
# │ {1m 17s,191}         │
# │ {1h 32m 25s,1}       │
# │ {18h 23m 6s,3}       │
# │ {4d 18h 28m 5s,8}    │
# │ {4m 44s,144}         │
# │ {4m 3s,13}           │
# │ {5m 12s,2}           │
# │ {1h 32m 57s,1}       │
# │ {16m 51s,1}          │
# │ {2m 26s,19}          │
# │ {18h 24m 9s,3}       │
# │ {4m 8s,9}            │
# │ {3d 18h 24m 56s,15}  │
# │ {7d 18h 27m 52s,5}   │
# │ {14m 34s,1}          │
# │ {23h 59m 59s,2}      │
# │ {14m 35s,5}          │
# │ {3d 18h 27m 55s,7}   │
# │ {3m 14s,205}         │
# │ {1m 34s,101}         │
# └──────────────────────┘

# %%
x.sort('datetime')
# Out:
# shape: (1_347, 1)
# ┌──────────────────────┐
# │ datetime             │
# │ ---                  │
# │ struct[2]            │
# ╞══════════════════════╡
# │ {null,37}            │
# │ {0ms,14674}          │
# │ {1s,4019448}         │
# │ {2s,15850625}        │
# │ {3s,166547691}       │
# │ {4s,18554633}        │
# │ {5s,44602178}        │
# │ {6s,17586926}        │
# │ {7s,3045286}         │
# │ {8s,1929053}         │
# │ {9s,5394288}         │
# │ {10s,5831254}        │
# │ {11s,597792}         │
# │ {12s,1951290}        │
# │ {13s,248556}         │
# │ {14s,282042}         │
# │ {15s,2372321}        │
# │ {16s,133994}         │
# │ {17s,85238}          │
# │ {18s,503307}         │
# │ {19s,82096}          │
# │ {20s,652884}         │
# │ {21s,306398}         │
# │ {22s,31914}          │
# │ {23s,27577}          │
# │ {24s,192527}         │
# │ {25s,323902}         │
# │ {26s,23451}          │
# │ {27s,119819}         │
# │ {28s,13310}          │
# │ {29s,14632}          │
# │ {30s,257631}         │
# │ {31s,11530}          │
# │ {32s,7273}           │
# │ {33s,55420}          │
# │ {34s,8373}           │
# │ {35s,106229}         │
# │ {36s,42047}          │
# │ {37s,4352}           │
# │ {38s,3749}           │
# │ {39s,30135}          │
# │ {40s,67149}          │
# │ {41s,4591}           │
# │ {42s,21456}          │
# │ {43s,2531}           │
# │ {44s,2947}           │
# │ {45s,59091}          │
# │ {46s,3266}           │
# │ {47s,1630}           │
# │ {48s,12660}          │
# │ {49s,1955}           │
# │ {50s,30997}          │
# │ {51s,10783}          │
# │ {52s,1192}           │
# │ {53s,1008}           │
# │ {54s,7874}           │
# │ {55s,22426}          │
# │ {56s,1534}           │
# │ {57s,6224}           │
# │ {58s,771}            │
# │ {59s,714}            │
# │ {1m,21780}           │
# │ {1m 1s,1044}         │
# │ {1m 2s,505}          │
# │ {1m 3s,3843}         │
# │ {1m 4s,651}          │
# │ {1m 5s,11638}        │
# │ {1m 6s,3441}         │
# │ {1m 7s,389}          │
# │ {1m 8s,330}          │
# │ {1m 9s,2673}         │
# │ {1m 10s,8672}        │
# │ {1m 11s,607}         │
# │ {1m 12s,2081}        │
# │ {1m 13s,269}         │
# │ {1m 14s,303}         │
# │ {1m 15s,8043}        │
# │ {1m 16s,503}         │
# │ {1m 17s,191}         │
# │ {1m 18s,1493}        │
# │ {1m 19s,259}         │
# │ {1m 20s,5063}        │
# │ {1m 21s,1502}        │
# │ {1m 22s,185}         │
# │ {1m 23s,128}         │
# │ {1m 24s,1070}        │
# │ {1m 25s,3983}        │
# │ {1m 26s,262}         │
# │ {1m 27s,926}         │
# │ {1m 28s,136}         │
# │ {1m 29s,126}         │
# │ {1m 30s,3797}        │
# │ {1m 31s,231}         │
# │ {1m 32s,81}          │
# │ {1m 33s,680}         │
# │ {1m 34s,101}         │
# │ {1m 35s,2622}        │
# │ {1m 36s,732}         │
# │ {1m 37s,69}          │
# │ {1m 38s,55}          │
# │ …                    │
# │ {8d 18h 24m 47s,3}   │
# │ {8d 18h 24m 48s,16}  │
# │ {8d 18h 24m 49s,1}   │
# │ {8d 18h 24m 50s,1}   │
# │ {8d 18h 24m 51s,3}   │
# │ {8d 18h 25m,1}       │
# │ {8d 18h 25m 2s,1}    │
# │ {8d 18h 25m 4s,1}    │
# │ {8d 18h 27m 56s,1}   │
# │ {9d 18h 24m 38s,1}   │
# │ {9d 18h 24m 42s,1}   │
# │ {9d 18h 24m 43s,1}   │
# │ {9d 18h 24m 44s,6}   │
# │ {9d 18h 24m 45s,6}   │
# │ {9d 18h 24m 46s,36}  │
# │ {9d 18h 24m 47s,10}  │
# │ {9d 18h 24m 48s,25}  │
# │ {9d 18h 24m 49s,23}  │
# │ {9d 18h 24m 50s,9}   │
# │ {9d 18h 24m 51s,39}  │
# │ {9d 18h 24m 52s,7}   │
# │ {9d 18h 24m 53s,11}  │
# │ {9d 18h 24m 54s,3}   │
# │ {9d 18h 24m 55s,3}   │
# │ {9d 18h 24m 56s,1}   │
# │ {9d 18h 24m 57s,5}   │
# │ {9d 18h 24m 58s,9}   │
# │ {9d 18h 24m 59s,7}   │
# │ {9d 18h 25m,15}      │
# │ {9d 18h 25m 1s,1}    │
# │ {9d 18h 25m 2s,4}    │
# │ {9d 18h 25m 3s,6}    │
# │ {9d 18h 25m 4s,8}    │
# │ {9d 18h 25m 6s,1}    │
# │ {9d 18h 25m 8s,1}    │
# │ {9d 18h 25m 9s,1}    │
# │ {9d 18h 27m 51s,2}   │
# │ {9d 18h 27m 52s,6}   │
# │ {9d 18h 27m 53s,11}  │
# │ {9d 18h 27m 54s,1}   │
# │ {9d 18h 27m 55s,2}   │
# │ {9d 18h 27m 58s,2}   │
# │ {9d 18h 28m,1}       │
# │ {9d 18h 28m 1s,1}    │
# │ {9d 18h 28m 2s,2}    │
# │ {9d 18h 28m 3s,3}    │
# │ {9d 18h 28m 4s,3}    │
# │ {9d 18h 28m 5s,2}    │
# │ {9d 18h 28m 6s,4}    │
# │ {9d 18h 28m 7s,3}    │
# │ {9d 18h 28m 8s,3}    │
# │ {9d 18h 28m 9s,3}    │
# │ {9d 18h 28m 10s,1}   │
# │ {9d 18h 28m 11s,2}   │
# │ {9d 18h 28m 12s,1}   │
# │ {9d 18h 28m 18s,1}   │
# │ {10d 18h 24m 35s,1}  │
# │ {10d 18h 24m 38s,2}  │
# │ {10d 18h 24m 41s,2}  │
# │ {10d 18h 24m 43s,4}  │
# │ {10d 18h 24m 44s,4}  │
# │ {10d 18h 24m 45s,6}  │
# │ {10d 18h 24m 46s,20} │
# │ {10d 18h 24m 47s,9}  │
# │ {10d 18h 24m 48s,25} │
# │ {10d 18h 24m 49s,12} │
# │ {10d 18h 24m 50s,5}  │
# │ {10d 18h 24m 51s,7}  │
# │ {10d 18h 24m 52s,4}  │
# │ {10d 18h 24m 55s,1}  │
# │ {10d 18h 24m 57s,1}  │
# │ {10d 18h 28m 11s,1}  │
# │ {11d 18h 24m 47s,1}  │
# │ {11d 18h 25m 4s,1}   │
# │ {11d 18h 28m 7s,1}   │
# │ {11d 20h 56m 38s,1}  │
# │ {12d 18h 28m 31s,1}  │
# │ {14d 18h 24m 47s,1}  │
# │ {14d 18h 24m 48s,1}  │
# │ {16d 18h 24m 49s,1}  │
# │ {16d 18h 28m 6s,1}   │
# │ {17d 18h 28m 5s,1}   │
# │ {21d 18h 24m 50s,1}  │
# │ {22d 18h 24m 41s,1}  │
# │ {25d 18h 24m 46s,1}  │
# │ {27d 18h 24m 42s,1}  │
# │ {29d 18h 24m 39s,1}  │
# │ {40d 18h 28m 1s,1}   │
# │ {67d 18h 27m 53s,1}  │
# │ {90d 18h 24m 46s,1}  │
# │ {93d 18h 24m 52s,1}  │
# │ {95d 18h 24m 48s,1}  │
# │ {103d 18h 28m 9s,1}  │
# │ {111d 18h 24m 48s,1} │
# │ {149d 18h 24m 59s,1} │
# │ {153d 18h 24m 50s,1} │
# │ {155d 18h 27m 51s,1} │
# │ {202d 18h 25m 5s,1}  │
# │ {358d 18h 27m 53s,1} │
# └──────────────────────┘
